# %% [markdown]
# <a href="https://colab.research.google.com/github/sahil3Vedi/Enron-Email-Classifier/blob/master/BagOfWords_Formal_Informal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('words')
from collections import Counter
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
main_dict = {}
stop_words = set(stopwords.words('english'))
def scanMail(mail_string):
  res = re.findall(r'\w+', mail_string)
  res.pop(0)
  final_res = []
  for each_word in res:
    if ((each_word.isalpha()) and (each_word not in stop_words)) :
      final_res.append(each_word)
      if each_word in main_dict:
        main_dict[each_word] += 1
      else:
        main_dict[each_word] = 1

  return final_res

# %%
ENRONNOSPAMDATASET = 'drive/My Drive/Enron Spam/ham'

for each_file in os.listdir(ENRONNOSPAMDATASET):
  FILENAME = os.path.join(ENRONNOSPAMDATASET, each_file)
  #print(FILENAME)
  with open(FILENAME, 'r',encoding='utf-8',errors='ignore') as myfile:
    data = myfile.read()
    word_list = scanMail(data)

print(main_dict)
# Out:
# {'f': 242, 'hpl': 2322, 'nom': 833, 'eff': 34, 'may': 960, 'nomination': 587, 'available': 201, 'today': 313, 'rolled': 28, 'april': 512, 'made': 209, 'retroactive': 14, 'bob': 710, 'forwarded': 1298, 'robert': 875, 'cotten': 321, 'hou': 7284, 'ect': 13902, 'pm': 2327, 'withers': 96, 'e': 1342, 'mail': 648, 'cc': 2361, 'tom': 295, 'acton': 143, 'knox': 18, 'westmoreland': 17, 'stretch': 39, 'brennan': 37, 'subject': 2733, 'estimated': 63, 'josey': 49, 'ranch': 149, 'month': 780, 'volume': 877, 'effective': 449, 'mmbtu': 1353, 'day': 875, 'kcs': 84, 'resources': 251, 'texaco': 56, 'total': 274, 'assumed': 14, 'btu': 75, 'factor': 22, 'dry': 20, 'need': 1259, 'additional': 194, 'information': 635, 'field': 170, 'contact': 360, 'victoria': 43, 'energy': 665, 'inc': 249, 'san': 45, 'felipe': 22, 'suite': 90, 'houston': 450, 'tx': 229, 'voice': 55, 'fax': 235, 'tenaska': 431, 'iv': 308, 'daren': 1901, 'add': 143, 'sale': 411, 'demand': 207, 'fee': 222, 'deal': 2790, 'spreadsheet': 179, 'mark': 325, 'shows': 118, 'already': 118, 'agency': 53, 'let': 1089, 'know': 1442, 'thanks': 1818, 'megan': 310, 'revision': 122, 'enron': 6556, 'actuals': 330, 'sept': 138, 'september': 287, 'teco': 444, 'tap': 343, 'iferc': 185, 'ls': 177, 'lsk': 123, 'ic': 122, 'gas': 2864, 'daily': 556, 'c': 351, 'melissa': 462, 'jones': 176, 'texas': 796, 'utilities': 239, 'charlie': 130, 'stone': 128, 'tu': 285, 'gary': 561, 'green': 57, 'j': 1302, 'farmer': 1137, 'com': 2718, 'hanks': 217, 'carlos': 191, 'rodriguez': 142, 'earl': 80, 'tisdale': 74, 'ami': 401, 'chokshi': 309, 'cornhusker': 136, 'management': 315, 'thought': 91, 'might': 107, 'helpful': 22, 'summarize': 3, 'next': 296, 'steps': 24, 'agreed': 47, 'necessary': 92, 'put': 197, 'agreement': 372, 'place': 181, 'desk': 339, 'ponderosa': 6, 'pine': 18, 'llc': 47, 'mazowita': 52, 'work': 292, 'plant': 471, 'manager': 195, 'mike': 197, 'gough': 10, 'determine': 64, 'power': 143, 'schedules': 18, 'received': 220, 'brazos': 63, 'translated': 3, 'fuel': 263, 'requirements': 80, 'operating': 118, 'flexibility': 11, 'use': 273, 'oil': 291, 'natural': 183, 'built': 21, 'dispatch': 5, 'operation': 9, 'decision': 21, 'degree': 5, 'historically': 13, 'involved': 46, 'suppliers': 10, 'beyond': 11, 'tgc': 8, 'apache': 96, 'williams': 91, 'lone': 92, 'star': 101, 'nancy': 15, 'stivers': 12, 'structural': 4, 'differences': 11, 'supply': 238, 'agreements': 26, 'experience': 44, 'optimizing': 2, 'value': 69, 'form': 119, 'within': 118, 'ena': 732, 'transactions': 71, 'nature': 7, 'lyons': 18, 'hill': 83, 'project': 111, 'vs': 48, 'holding': 18, 'company': 467, 'level': 66, 'b': 366, 'bank': 24, 'approvals': 3, 'needed': 151, 'result': 35, 'new': 1003, 'draft': 67, 'griffith': 22, 'best': 116, 'means': 35, 'handling': 47, 'duel': 2, 'capability': 11, 'aside': 3, 'passed': 23, 'gave': 46, 'meeting': 266, 'concerning': 38, 'tax': 108, 'certificate': 28, 'rhett': 3, 'jackson': 57, 'handled': 29, 'related': 73, 'matters': 15, 'acquisition': 13, 'phase': 8, 'please': 2718, 'keep': 183, 'loop': 14, 'contacts': 29, 'help': 388, 'meter': 2459, 'concorde': 1, 'churchill': 1, 'one': 543, 'year': 238, 'rate': 223, 'mm': 92, 'volumes': 790, 'greater': 55, 'price': 735, 'less': 290, 'plus': 53, 'per': 456, 'metering': 2, 'would': 875, 'cover': 117, 'transport': 385, 'competitive': 10, 'ship': 38, 'channel': 77, 'market': 135, 'equistar': 177, 'channelview': 8, 'rates': 134, 'term': 187, 'significantly': 8, 'different': 101, 'assume': 33, 'start': 151, 'good': 170, 'friday': 307, 'august': 318, 'get': 795, 'em': 8, 'hot': 8, 'logistics': 180, 'powerpoint': 11, 'presentation': 29, 'hi': 90, 'friendly': 9, 'reminder': 31, 'tomorrow': 150, 'october': 331, 'th': 706, 'time': 635, 'assistance': 66, 'call': 619, 'questions': 764, 'elizabeth': 87, 'x': 472, 'located': 39, 'presentations': 12, 'powerpointl': 2, 'ppt': 7, 'original': 506, 'message': 669, 'webb': 19, 'sent': 637, 'thursday': 222, 'lamadrid': 87, 'victor': 133, 'kinsey': 50,  ...

# %%
def getCommon(new_dict, n):
  temp_dict = new_dict
  ret_dict = {}
  for i in range(n):
    Keymax = max(temp_dict, key=temp_dict.get)
    ret_dict[Keymax]=temp_dict[Keymax]
    del temp_dict[Keymax]
  return ret_dict

# %%
final_dict = getCommon(main_dict,1000)

import csv
with open('drive/My Drive/Enron Spam/bagofwords_formal_informal.csv', 'w') as f:
    for key in final_dict.keys():
        f.write("%s,%s\n"%(key,final_dict[key]))
